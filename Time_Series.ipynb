# %%
import pandas as pd

# %%
cdata=pd.read_csv("/Users/C4/New_data.csv",index_col ="Country")

# %%
cdata
# Out:
#          Country ID  Year  NumberOfReportedCasesOfCholera        CPRE  \
# Country
# Burundi           1  1978                          8297.0  108.300000
# Burundi           1  1979                           915.0  110.900000
# Burundi           1  1980                          2039.0   93.100000
# Burundi           1  1981                           582.0  104.800000
# Burundi           1  1982                           415.0  102.000000
# ...             ...   ...                             ...         ...
# DRC               6  2012                         33661.0  133.650000
# DRC               6  2013                         26944.0  140.833333
# DRC               6  2014                         22203.0  140.833333
# DRC               6  2015                         19182.0  140.833333
# DRC               6  2016                         28093.0  140.833333
#
#               CTMP       CTMN       CTMX       CWET       CVAP       CDTR  \
# Country
# ...

# %%
Burundi = cdata.loc["Burundi"]
DRC = cdata.loc["DRC"]
Rwanda = cdata.loc["Rwanda"]
Uganda =cdata.loc["Uganda"]
Kenya=cdata.loc["Kenya"]
Tanzania=cdata.loc[" Tanzania"]

# %%
from pandas import read_csv
from matplotlib import pyplot
import matplotlib.pyplot as plt
plt.plot(Burundi.Year ,Burundi.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Burundi")
# Out:
# Text(0.5, 1.0, 'Burundi')

# %%
from pandas import read_csv
from matplotlib import pyplot
import matplotlib.pyplot as plt
plt.plot(DRC.Year ,DRC.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("DRC")
# Out:
# Text(0.5, 1.0, 'DRC')

# %%
plt.plot(Rwanda.Year ,Rwanda.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Rwanda")
# Out:
# Text(0.5, 1.0, 'Rwanda')

# %%
plt.plot(Uganda.Year ,Uganda.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Uganda")
# Out:
# Text(0.5, 1.0, 'Uganda')

# %%
plt.plot(Kenya.Year ,Kenya.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Kenya")
# Out:
# Text(0.5, 1.0, 'Kenya')

# %%
plt.plot(Kenya.Year ,Kenya.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Kenya")
# Out:
# Text(0.5, 1.0, 'Kenya')

# %%
plt.plot(Tanzania.Year ,Tanzania.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Tanzania")
# Out:
# Text(0.5, 1.0, 'Tanzania')

# %%
# Import library


import matplotlib.pyplot as plt

plt.figure(figsize=(20,20))

# Create figure and multiple plots
fig, axes = plt.subplots(nrows=3, ncols=2)

# Auto adjust
plt.subplot(3, 2, 1)

plt.plot(Burundi.Year ,Burundi.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Burundi")




plt.subplot(3, 2, 2)

plt.plot(Tanzania.Year ,Tanzania.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Tanzania")



plt.subplot(3, 2, 3)

plt.plot(Kenya.Year ,Kenya.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Kenya")



plt.subplot(3, 2, 4)
plt.plot(Uganda.Year ,Uganda.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Uganda")

plt.subplot(3, 2, 5)
plt.plot(Rwanda.Year ,Rwanda.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("Rwanda")


plt.subplot(3, 2, 6)
plt.plot(DRC.Year ,DRC.NumberOfReportedCasesOfCholera,label='blogs_read', 
         linewidth=3)
plt.title("DRC")


plt.tight_layout()
plt.show()
# Display
